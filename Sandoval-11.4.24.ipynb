# %% [markdown]
# Creating the an ordinal rank column for each sumo wrestler.
# get_ordinal_rank function in sumo.py takes a dataframe and two columns
# 1. 'rikishi1_sortable_rank' that is a numeric sortable string from 'rikishi1_rank'
# 2. 'ordinal_rank', an integer column by sorting 'rikishi1_sortable rank' and assigning a integer value
# 3. Will have to be applied by year

# %%
import pandas as pd
import numpy as np

from sumo import *

#Add the path to the folder that contains the data. Makes it easier for each of us to use the notebook
#path = "/Users/Kyla/Desktop/ErdosDataScienceWork/Project/"
path = "data/"

df = pd.read_csv(path+str(1983)+'.csv')

# %%
x = df.sort_values(by = 'rikishi1_id').value_counts('rikishi1_id')

# %%
# returning a dataframe columns df['rikishi1_sortable_rank'] and df['ordinal_rank'] added
df = get_ordinal_rank(df)

# %%
df.sort_values(by='r1_ord_rank')
df
# Out:
#       index    basho  day  rikishi1_id rikishi1_rank rikishi1_shikona  \
# 0         0  1983.01    1         4140          J13w      Chikubayama
# 1         1  1983.01    1         4306          Ms1e            Ofuji
# 2         2  1983.01    1         1337          J12w     Tochitsukasa
# 3         3  1983.01    1         4323          J13e         Shiraiwa
# 4         4  1983.01    1         4097          J12e       Tamakiyama
# ...     ...      ...  ...          ...           ...              ...
# 5483   5483  1983.11   15         4104           Y1e       Takanosato
# 5484   5484  1983.11   16         1348           J4w          Jingaku
# 5485   5485  1983.11   16         1378           J1w              Hoo
# 5486   5486  1983.11   16         1287          J12w        Konishiki
# 5487   5487  1983.11   16         1378           J1w              Hoo
#
#      rikishi1_result  rikishi1_win   kimarite  rikishi2_id rikishi2_rank  \
# ...

# %%
basho = df[ (df['rikishi1_id'] == 1354) & (df['basho'] == 1983.01 )]
basho.head(15)
# Out:
#      index    basho  day  rikishi1_id rikishi1_rank rikishi1_shikona  \
# 62      62  1983.01    1         1354           Y1e      Chiyonofuji
# 124    124  1983.01    2         1354           Y1e      Chiyonofuji
# 190    190  1983.01    3         1354           Y1e      Chiyonofuji
# 250    250  1983.01    4         1354           Y1e      Chiyonofuji
# 314    314  1983.01    5         1354           Y1e      Chiyonofuji
# 374    374  1983.01    6         1354           Y1e      Chiyonofuji
# 436    436  1983.01    7         1354           Y1e      Chiyonofuji
# 494    494  1983.01    8         1354           Y1e      Chiyonofuji
# 558    558  1983.01    9         1354           Y1e      Chiyonofuji
# 619    619  1983.01   10         1354           Y1e      Chiyonofuji
# 680    680  1983.01   11         1354           Y1e      Chiyonofuji
# 740    740  1983.01   12         1354           Y1e      Chiyonofuji
# 800    800  1983.01   13         1354           Y1e      Chiyonofuji
# ...

# %%
bash = df['basho'].unique()
print(bash)
# Out:
# [1983.01 1983.03 1983.05 1983.07 1983.09 1983.11]

# %%
#For a year and tournament [ '01', '03', '05' '07', '11]
df['year'] = df['basho'].astype(str).str.split('.').str[0].astype(int)
df['tourn'] = df['basho'].astype(str).str.split('.').str[1]
df['record'] = df['rikishi1_result'].astype(str).str.split('(').str[0]
df['day'] = df['day'].astype(int)

cols = ['rikishi1_id','year', 'tourn', 'day', 'rikishi1_win', 'r1_ord_rank', 'record']
df.sort_values(by=['r1_ord_rank', 'rikishi1_id', 'tourn', 'day'],  ascending = [True, True, True, True])
df['wins'] = df['record'].astype(str).str.split('-').str[0]
df['loses'] = df['record'].astype(str).str.split('-').str[1]

print(x=df['wins'].astype(int))
#df['loses'] = df['record'].astype(str).str.split('-').str[1].astype(int)
#uid = df['rikishi1_id'].unique()
#print(uid)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 12
#       9 df['wins'] = df['record'].astype(str).str.split('-').str[0]
#      10 df['loses'] = df['record'].astype(str).str.split('-').str[1]
# ---> 12 print(x=df['wins'].astype(int))
#
# File ~/.conda/envs/erdos/lib/python3.12/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# ...
