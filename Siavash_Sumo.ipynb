# %%
# Run next cell for better display

# %% [markdown]
# # [**Information needed**](#Rank-names)
# Rankings and their abbrevaitions goes as follows __[(here)](https://www.sumotalk.com/structure.htm)__:
# 1. The top division, called Makuuchi, includes the top 42 rikishi (Y). This division is known as the upper division and consists of 5 subdivisions
#     1. Yokozuna (Y)
#     1. Ozeki (O)
#     1. Sekiwake (S)
#     1. Komusubi (K)
#     1. Maegashira (M)
# 1. The second highest division is called Juryo. Juryo consists of 28 rikishi.
# 1. The third division is called Makushita. This division consists of 120 rikishi all fighting to be promoted to Juryo, thus becoming a sekitori.
# 1. The fourth division is Sandanme, which consists of approximately 200 rikishi.
# 1. The fifth division is Jonidan, which consists of approximately 260 rikishi.
# look at __[(here)](http://www.sumoforum.net/glossary.html#haridashi)__. In a compact form there is following picture.
#
#
#
# ![title](Images/pyramid.png)
#
#
# This constructs a string for a sumotori's rank. It takes three unnamed parameters. All are optional, but if none are given the results are very uninteresting. It's primarily intended for use by other templates, but it may have a broader application.
#
# 1. A 1 or 2 letter code for the rikishi's division or makuuchi rank:
#     * Y: Yokozuna
#     * YO: Yokozuna-Ōzeki
#     * O: Ōzeki
#     * S: Sekiwake
#     * K: Komosubi
#     * M: Maegashira
#     * J: Jūryō (I don't think we have any data about divisions below this one.)
#     * Ms: Makushita
#     * MT: Makushita tsukedashi
#     * SA: Sandanme
#     * ST: Sandanme tsukedashi
#     * JO: Jonidan
#     * JK: Jonokuchi
#     * BG: Banzuke-gai
#     * SD: Shin-deshi
#     * SJ: Shinjo
# 1. Number within division or rank, or H for sanyaku and maegashira haridashi
# 1. E or W for East or West
#
#
# ## More comprehensive description
#
# **Maezmo:** Not really a rank, but brand new wrestlers get introduced in a special ceremony and fight a 7-day tournament just amongst themselves to see where they get placed in the lowest official ranking. Gives them a taste for how a tournament goes.
#
# **Jonokuchi, Jonidan, and Sandanme:** These are all beginner rankings. The names roughly mean "Beginning step", "2nd beginning grade", and "3rd grade". Everyone here is getting their skills. Most wrestlers here are quite young. Professional sumo training starts as early as 15 years of age. You can also find older wrestlers or wrestlers who were out with injuries for several tournaments and fell hard.
#
#
# **Makushita:** This is the top of the non-salaried rankings and is fixed at 60 ranks (120 wrestlers). The name literally means "below the curtain". This is a hard division. Breaking out of this rank into the next one is the tipping point between getting a salary or not. If you do especially well in this rank (7-0 records) then you can get a huge boost either within Makushita or go directly to the next rank.
#
# **Juryo:** The name derives from an old unit of payment and means that the wrestlers are getting paid. Juryo is fixed at 14 ranks (28 wrestlers). This rank is full of up-and-comers mixed with people falling down from Maegashira. Main goal for this rank, don't fall down out of it. You don't keep getting paid if you leave it! Also, all ranks from here on fight the full 15 days. Juryo matches used to be televised, but not so much these days.
#
# **Side note:** All the ranks above Juryo are upper division ranks (Makuuchi, "inside the curtain"). Wrestlers get many more privileges at this point. They also get televised on NHK. Most wrestlers you hear about will have hit this division.
#
#
# **Maegashira:** Roughly means "those in front." NHK likes to call this division "rank-and-filers", though as you can see from the number of people they've surpassed that's not quite accurate. At maximum, there are 16 ranks (32 wrestlers) in the Maegashira division. If there are more people in higher ranks, there are fewer Maegashira ranks to keep the 42 wrestler total.
#
# **Side note:** These last ranks are called san'yaku, or titleholder ranks. Even if a wrestler drops out of these ranks, they will be known by the highest rank they achieved.
#
# **Komusubi:** "The little knot". There must always be two wrestlers at this rank. More can be added if a Maegashira does so well that the banzuke creators deem they can't be denied promotion. The reason is that the rank is called a knot is that a wrestler at this rank has to either wait for a space to open up at the next rank or do so well that they can't be denied a promotion (think 11+ wins). Quite possibly the hardest rank to hold out of all of them.
#
# **Sekiwake:** "At the side of the barrier". Also must always be two wrestlers at this rank. To progress from here, the standard is 33 wins across three consecutive tournaments. Thus, they have to win 73.33% of the time in three matches without getting make-kochi. Very difficult to do. There is also an separate committee that looks at the wrestler's history to see if their comportment and prowess are worthy of the promotion to...
#
# **Ozeki:** "Great Barrier". Used to be the highest rank before Yokozuna. Losing this rank requires two losing tournaments in a row. A single losing tournament puts an Ozeki into a status called "kadoban".If they get a winning tournament, the status is lifted. If he loses again, it's back to Sekiwake. If they can get 10 wins in the next tournament, they'll get their Ozeki status again. If they can't, they'll have to start the process to getting to Ozeki all over again.
#
# **Yokozuna:** "Horizontal Rope", after the tsuna they wear in their special entrance ceremony. The current standard to achieve this rank is to win two back-to-back tournaments as an Ozeki. They must also undergo a stringent examination of character by both the Sumo Association and a body of laypeople called the Yokozuna Deliberation Council. Once they are promoted, they cannot be demoted. However, if they cannot uphold the rank they are expected to retire from the sport. There have only been 72 wrestlers to officially achieve this rank in all of Sumo's history.
#
# ## Ranking before 1995
#
# **haridashi** (張り出し)
# Overhang. If there are more than two wrestlers at any san'yaku rank, the additional wrestlers are termed haridashi. Prior to 1995, such wrestlers were listed on the banzuke in extensions or "overhangs" to the row for makuuchi wrestlers. This is now an informal designation, since presently all wrestlers are listed within the normal bounds of the row. __[(link)](https://sumowrestling.fandom.com/wiki/Glossary_of_Sumo_Terms)__

# %%
import pandas as pd
print(2+2)
# Out:
# 4

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('data/1983.csv')

# Display the DataFrame
print(df)

# erase some of the rows to make it smaller
reduced_df = df.iloc[:10]  


# Save the reduced DataFrame to a new CSV file
reduced_df.to_csv('test2.csv', index=False)


# Display the reduced DataFrame:

print("reduced DataFrame:")
print(reduced_df)
# Out:
#       index    basho  day  rikishi1_id rikishi1_rank rikishi1_shikona  \
# 0         0  1983.01    1         4140          J13w      Chikubayama
# 1         1  1983.01    1         4306          Ms1e            Ofuji
# 2         2  1983.01    1         1337          J12w     Tochitsukasa
# 3         3  1983.01    1         4323          J13e         Shiraiwa
# 4         4  1983.01    1         4097          J12e       Tamakiyama
# ...     ...      ...  ...          ...           ...              ...
# 5483   5483  1983.11   15         4104           Y1e       Takanosato
# 5484   5484  1983.11   16         1348           J4w          Jingaku
# 5485   5485  1983.11   16         1378           J1w              Hoo
# 5486   5486  1983.11   16         1287          J12w        Konishiki
# 5487   5487  1983.11   16         1378           J1w              Hoo
#
#      rikishi1_result  rikishi1_win   kimarite  rikishi2_id rikishi2_rank  \
# ...

# %%
# Change the ranking column

string_rank = reduced_df['rikishi1_rank'].astype(str).tolist()

# Display the new string array
print(string_rank)
# Out:
# ['J13w', 'Ms1e', 'J12w', 'J13e', 'J12e', 'J11w', 'J10w', 'J11e', 'J10e', 'J9w']

# %%
# This cell is written for changing the strings in some columns to numbers and adding that to the csv file.

new_column_name = 'NumericRank'
new_column_values = ['*']*5488 

# Insert the new column at the desired position (e.g., index 5)
# Here, index 5 means the new column will be the sixth column

df.insert(5, new_column_name, new_column_values)

print(df)
# Out:
#       index    basho  day  rikishi1_id rikishi1_rank NumericRank  \
# 0         0  1983.01    1         4140          J13w           *
# 1         1  1983.01    1         4306          Ms1e           *
# 2         2  1983.01    1         1337          J12w           *
# 3         3  1983.01    1         4323          J13e           *
# 4         4  1983.01    1         4097          J12e           *
# ...     ...      ...  ...          ...           ...         ...
# 5483   5483  1983.11   15         4104           Y1e           *
# 5484   5484  1983.11   16         1348           J4w           *
# 5485   5485  1983.11   16         1378           J1w           *
# 5486   5486  1983.11   16         1287          J12w           *
# 5487   5487  1983.11   16         1378           J1w           *
#
#      rikishi1_shikona rikishi1_result  rikishi1_win   kimarite  rikishi2_id  \
# 0         Chikubayama       0-1 (7-8)             0   yorikiri         4306
# ...

# %%
# This is to save the csv file with a new name.

df.to_csv('test_v1.csv', index=False)

# %% [markdown]
# # Finishing Move:
# kimarite, winning technique; currently there are 82 kimarite listed __[(link)](http://www.sumoforum.net/glossary.html#koshikudake)__. For more pictures look at the this website __[(link)](https://sports.japantimes.co.jp/sumo/techniques.html)__.
#
#  Look at __[(link)](https://fight-library.com/2020/03/07/sumo-wrestling-terms-a-westerners-glossary/)__

# %%
import csv

def get_unique_entries(csv_file_path, column_name):
    unique_entries = set()  

    with open(csv_file_path, mode='r', encoding='utf-8') as file:
        reader = csv.DictReader(file)  # Read CSV as dictionary
        for row in reader:
            if column_name in row:
                unique_entries.add(row[column_name])  # Add each entry in the column to the set

    return unique_entries

# Example usage
csv_file_path = 'data/1983.csv'  
column_name = 'kimarite'  

unique_entries = get_unique_entries(csv_file_path, column_name)
print("Unique entries in the column:", unique_entries)
# Out:
# Unique entries in the column: {'abisetaoshi', 'okuridashi', 'makiotoshi', 'tsuridashi', 'komatasukui', 'fusen', 'katasukashi', 'uwatenage', 'uwatedashinage', 'yoritaoshi', 'uwatehineri', 'kawazugake', 'sabaori', 'okuritaoshi', 'harimanage', 'oshidashi', 'tottari', 'kainahineri', 'hikiotoshi', 'oshitaoshi', 'shitatenage', 'sotogake', 'kotenage', 'amiuchi', 'utchari', 'uchigake', 'shitatedashinage', 'kekaeshi', 'hatakikomi', 'tsukidashi', 'tsukiotoshi', 'uchimuso', 'kubinage', 'yobimodoshi', 'ketaguri', 'shitatehineri', 'kakenage', 'ashitori', 'isamiashi', 'sukuinage', 'tsuriotoshi', 'kirikaeshi', 'kimedashi', 'susoharai', 'yorikiri', 'tsukitaoshi', 'nichonage'}

# %% [markdown]
# Here I am trying to find different finishing moves to write something about them.

# %%
import pandas as pd

def get_unique_entries_with_counts(csv_file_path, column_name):
    
    df = pd.read_csv(csv_file_path, usecols=[column_name])

    # Normalize by stripping whitespace and converting to lowercase
    df[column_name] = df[column_name].astype(str).str.strip().str.lower()

    # Get the counts of each unique entry
    entry_counts = df[column_name].value_counts()

    return entry_counts

csv_file_path = 'data/1983.csv'  # This is the file path
column_name = 'kimarite'   #Not sure if all of the files have same name for finishing move

entry_counts = get_unique_entries_with_counts(csv_file_path, column_name)
print("Entry counts in the column:\n", entry_counts)
# Out:
# Entry counts in the column:
#  kimarite
# yorikiri            1764
# oshidashi            810
# hatakikomi           372
# uwatenage            358
# yoritaoshi           320
# tsukiotoshi          296
# hikiotoshi           188
# sukuinage            164
# shitatenage          146
# oshitaoshi           116
# tsuridashi           114
# kotenage             110
# tsukidashi           102
# okuridashi            94
# uwatedashinage        82
# sotogake              50
# fusen                 38
# katasukashi           36
# uwatehineri           28
# kekaeshi              26
# kimedashi             26
# kirikaeshi            24
# utchari               22
# abisetaoshi           22
# tsukitaoshi           20
# shitatedashinage      18
# kubinage              16
# makiotoshi            14
# ketaguri              14
# tottari               14
# kainahineri           14
# shitatehineri         10
# okuritaoshi            8
# uchimuso               8
# uchigake               6
# ...

# %%
import os
import pandas as pd

def get_unique_entries_with_counts(csv_file_path, column_name):
    # Read the specified column, if it exists in the CSV file
    df = pd.read_csv(csv_file_path, usecols=[column_name])
    # Normalize by stripping whitespace and converting to lowercase
    df[column_name] = df[column_name].astype(str).str.strip().str.lower()
    # Get the counts of each unique entry
    entry_counts = df[column_name].value_counts().reset_index()
    entry_counts.columns = [column_name, f"{os.path.basename(csv_file_path).replace('.csv', '')}_frequency"]

    return entry_counts

# Directory containing the CSV files
directory_path = 'data'
column_name = 'kimarite'  # Column name to look for in each file

# Dictionary to store the combined data
combined_data = pd.DataFrame()

# Loop through all CSV files in the directory
for filename in os.listdir(directory_path):
    if filename.endswith('.csv'):
        file_path = os.path.join(directory_path, filename)
        entry_counts = get_unique_entries_with_counts(file_path, column_name)
        if not entry_counts.empty:
            combined_data = combined_data.join(entry_counts.set_index(column_name), how='outer')

# Reset index to turn the unique entries into a column
combined_data_df = combined_data.reset_index()

# Display the final DataFrame
print("Combined data with separate columns for each file:\n", combined_data_df)

combined_data_df.to_csv('test2.csv', index=False)
# Out:
# Combined data with separate columns for each file:
#         kimarite  1990_frequency  1984_frequency  1985_frequency  \
# 0   abisetaoshi            14.0            34.0            36.0
# 1       amiuchi             4.0             2.0             2.0
# 2      ashitori             4.0             2.0             2.0
# 3      chongake             NaN             NaN             NaN
# 4     fumidashi             NaN             NaN             NaN
# ..          ...             ...             ...             ...
# 79   yaguranage             NaN             NaN             NaN
# 80  yobimodoshi             NaN             2.0             NaN
# 81     yorikiri          2062.0          1990.0          1988.0
# 82   yoritaoshi           216.0           310.0           250.0
# 83     zubuneri             NaN             NaN             NaN
#
#     1991_frequency  1987_frequency  1993_frequency  1992_frequency  \
# 0              6.0            18.0            12.0            16.0
# ...

# %%
import matplotlib.pyplot as plt

# Set 'Year' as the x-axis and plot frequencies of each unique 'kimarite'
plt.figure(figsize=(12, 12))

# Loop through each kimarite frequency column in the DataFrame
#for column in combined_data_df.columns:
#    plt.scatter(combined_data_df[0], combined_data_df[column], label=column.replace('_frequency', ''), alpha=0.6)
for i in range(1,3):
    plt.scatter(combined_data_df.iloc[:, i],combined_data_df.index, alpha=0.6)

plt.scatter(combined_data_df.iloc[:, 9],combined_data_df.index, color='blue', alpha=0.6)
plt.scatter(combined_data_df.iloc[:, 8],combined_data_df.index, color='red', alpha=0.6)

# Labeling the plot
plt.xlabel("Year")
plt.ylabel("Frequency of Kimarite")
plt.title("Scatter Plot of Years vs. Kimarite Frequencies")
plt.legend(title="Kimarite")
plt.show()
# Out:
# /var/folders/zb/s9y25xv57sd631cqzphbhf4r0000gn/T/ipykernel_90410/1434163364.py:19: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title="Kimarite")

# %% [markdown]
# Quantify the finishing moves:
