# %% [markdown]
# First, we'll make a pandas dataframe. Let's just use the 1983 data for now. Since I know how to concatenate data frames now, we can deal the rest of the data later.

# %%
import pandas as pd

df1983 = pd.read_csv('/Users/Kyla/Desktop/ErdosDataScienceWork/Project/data/1983.csv')

# %%
df1983
# Out:
#       index    basho  day  rikishi1_id rikishi1_rank rikishi1_shikona  \
# 0         0  1983.01    1         4140          J13w      Chikubayama
# 1         1  1983.01    1         4306          Ms1e            Ofuji
# 2         2  1983.01    1         1337          J12w     Tochitsukasa
# 3         3  1983.01    1         4323          J13e         Shiraiwa
# 4         4  1983.01    1         4097          J12e       Tamakiyama
# ...     ...      ...  ...          ...           ...              ...
# 5483   5483  1983.11   15         4104           Y1e       Takanosato
# 5484   5484  1983.11   16         1348           J4w          Jingaku
# 5485   5485  1983.11   16         1378           J1w              Hoo
# 5486   5486  1983.11   16         1287          J12w        Konishiki
# 5487   5487  1983.11   16         1378           J1w              Hoo
#
#      rikishi1_result  rikishi1_win   kimarite  rikishi2_id rikishi2_rank  \
# ...

# %% [markdown]
# Here's a function that tells us actual rank given a row of the data frame above. This is just a prototype to figue out what's going wrong.

# %%
def nonsumorank(row):
    counter = 1
    if df1983['rikishi1_rank'][row] == 'M'+str(counter)+'e':
        return counter
    if df1983['rikishi1_rank'][row] == 'M'+str(counter)+'w':
        return counter + 1
    else:
        return 0

# %% [markdown]
# This works fine. We can even test it on a given row.

# %%
print(nonsumorank(10))
print(df1983['rikishi1_rank'][10])
# Out:
# 0
# J9e

# %% [markdown]
# But when we put it into the data frame, something goes wrong. What is going wrong?

# %%
df1983['rikishi1_nonsumorank'] = df1983.apply(nonsumorank, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df1983['rikishi1_nonsumorank'] = df1983.apply(nonsumorank, axis=1)
#
# File /opt/anaconda3/envs/erdos_fall_2024/lib/python3.12/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File /opt/anaconda3/envs/erdos_fall_2024/lib/python3.12/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# ...
